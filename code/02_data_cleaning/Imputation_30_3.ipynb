# %%
import numpy as np
import pandas as pd
from sklearn.experimental import enable_iterative_imputer  # 启用 IterativeImputer
from sklearn.impute import SimpleImputer, KNNImputer, IterativeImputer
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import ParameterGrid

# %%
def preprocess_data(df, missing_threshold):
    """
    Removes rows with more than `missing_threshold`% missing values.
    
    Parameters:
    df (pd.DataFrame): Original dataset
    missing_threshold (float): Threshold for row removal (0.0 - 1.0)
    
    Returns:
    (pd.DataFrame, int): Cleaned dataset, number of removed rows
    """
    row_missing_percentage = df.isnull().mean(axis=1)  # 计算每行缺失值的比例
    cleaned_data = df[row_missing_percentage <= missing_threshold].copy()
    removed_rows = df.shape[0] - cleaned_data.shape[0]  # 计算删除的行数
    return cleaned_data, removed_rows

# %%
def create_masked_dataframe(df, mask_ratio=0.1, random_state=42):
    """
    Randomly masks a fraction of numeric values in df.
    
    Parameters:
    df (pd.DataFrame): The dataset with missing values
    mask_ratio (float): Proportion of values to mask (0 - 1)
    random_state (int): Random seed for reproducibility
    
    Returns:
    (pd.DataFrame, dict): Masked dataframe, dictionary of masked locations
    """
    np.random.seed(random_state)
    df_masked = df.copy()
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    mask_info = {}  # 记录被遮盖的数值位置
    
    for col in numeric_cols:
        non_missing_indices = df_masked.index[df_masked[col].notna()]
        n_to_mask = int(len(non_missing_indices) * mask_ratio)
        masked_indices = np.random.choice(non_missing_indices, size=n_to_mask, replace=False)
        
        mask_col = np.zeros(df_masked.shape[0], dtype=bool)
        mask_col[df_masked.index.get_indexer(masked_indices)] = True
        mask_info[col] = mask_col
        
        df_masked.loc[masked_indices, col] = np.nan
    
    return df_masked, mask_info

# %%
def grid_search_imputation(df, param_grid, mask_ratio=0.1, missing_threshold_list=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4], random_state=42):
    """
    Performs a grid search over imputation methods and missing data thresholds.
    
    Parameters:
    df (pd.DataFrame): The original dataframe
    param_grid (list of dict): List of imputation strategies and hyperparameters
    mask_ratio (float): Fraction of numeric values to mask
    missing_threshold_list (list): List of missing thresholds (proportion of missing values allowed per row)
    random_state (int): Random seed
    
    Returns:
    pd.DataFrame: Results sorted by MSE
    """
    all_results = []

    for missing_threshold in missing_threshold_list:
        # Step 1: Remove rows with excessive missing values
        cleaned_df, removed_rows = preprocess_data(df, missing_threshold)
        print(f"\nMissing Threshold: {missing_threshold*100}% - Removed Rows: {removed_rows}")

        # Step 2: Mask part of the data for evaluation
        df_original = cleaned_df.copy()
        df_masked, mask_info = create_masked_dataframe(df_original, mask_ratio, random_state)
        
        numeric_cols = df_original.select_dtypes(include=[np.number]).columns.tolist()
        if len(numeric_cols) == 0:
            continue

        all_params = list(ParameterGrid(param_grid))
        
        for param_dict in all_params:
            imputer_class = param_dict.get("imputer", None)
            if imputer_class is None:
                raise ValueError("Each param_dict must include 'imputer' key with an imputer object.")

            imputer = imputer_class
            for k, v in param_dict.items():
                if k.startswith("imputer__"):
                    param_name = k.split("__", 1)[1]
                    setattr(imputer, param_name, v)

            # Apply imputation
            imputed_array = imputer.fit_transform(df_masked[numeric_cols])
            imputed_df = pd.DataFrame(imputed_array, columns=numeric_cols, index=df_masked.index)

            method_mse_list = []
            method_mae_list = []

            # Step 4: Evaluate using MSE and MAE
            for col in numeric_cols:
                col_mask = mask_info[col]
                true_values = df_original.loc[col_mask, col]
                pred_values = imputed_df.loc[col_mask, col]

                if len(true_values) > 0:
                    mse = mean_squared_error(true_values, pred_values)
                    mae = mean_absolute_error(true_values, pred_values)
                    method_mse_list.append(mse)
                    method_mae_list.append(mae)

            avg_mse = np.mean(method_mse_list) if method_mse_list else None
            avg_mae = np.mean(method_mae_list) if method_mae_list else None

            all_results.append({
                "Missing_Threshold": missing_threshold,
                "Removed_Rows": removed_rows,
                "Params": param_dict,
                "MSE": avg_mse,
                "MAE": avg_mae
            })

    results_df = pd.DataFrame(all_results).sort_values(by=["Missing_Threshold", "MSE"], ascending=[True, True], na_position="last")
    return results_df

# %%
# Example Usage
data_path = "../data/final/nicu_30.csv"
df = pd.read_csv(data_path)

# Define imputation methods and hyperparameters
param_grid = [
    {
        "imputer": [SimpleImputer()],
        "imputer__strategy": ["mean", "median", "most_frequent"]
    },
    {
        "imputer": [KNNImputer()],
        "imputer__n_neighbors": [2, 5, 10]
    },
    {
        "imputer": [IterativeImputer(random_state=42)],
        "imputer__max_iter": [5, 10, 20],
    }
]

# Run the grid search for imputation
results_df = grid_search_imputation(
    df,
    param_grid=param_grid,
    mask_ratio=0.1,  # 随机遮盖 10% 的数值用于评估插补效果
    missing_threshold_list=[0.95, 0.9, 0.85, 0.8, 0.75, 0.7, 0.65, 0.6],  # 缺失阈值从 5% 到 40%，每 5% 一档
    random_state=42
)
# Out:
# Missing Threshold: 95.0% - Removed Rows: 2121
#
# Missing Threshold: 90.0% - Removed Rows: 2360
#
# Missing Threshold: 85.0% - Removed Rows: 2633
#
# Missing Threshold: 80.0% - Removed Rows: 3202
# C:\Users\littl\anaconda3\envs\thesis\lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Missing Threshold: 75.0% - Removed Rows: 3720
#
# Missing Threshold: 70.0% - Removed Rows: 4124
#
# Missing Threshold: 65.0% - Removed Rows: 5003
#
# Missing Threshold: 60.0% - Removed Rows: 5130

# %%
# Print results in a readable table format
print("\n===== Final Results =====")
print(results_df.to_string(index=False))

# Print best result
best_result = results_df.loc[results_df["MAE"].idxmin()]
print("\n===== Best Imputation Strategy =====")
print(f"Missing Threshold: {best_result['Missing_Threshold']*100}%")
print(f"Removed Rows: {best_result['Removed_Rows']}")
print(f"Best Params: {best_result['Params']}")
print(f"Best MSE: {best_result['MSE']:.6f}")
print(f"Best MAE: {best_result['MAE']:.6f}")
# Out:
# ===== Final Results =====
#  Missing_Threshold  Removed_Rows                                                                                     Params          MSE        MAE
#               0.60          5130        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 9.338594e+05  98.167994
#               0.60          5130          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 9.407449e+05  98.624872
#               0.60          5130        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 9.544182e+05  92.507468
#               0.60          5130       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 9.544182e+05  92.507468
#               0.60          5130       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 9.544182e+05  92.507468
#               0.60          5130                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.001245e+06  94.908805
#               0.60          5130                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.017008e+06  93.224829
#               0.60          5130                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 1.363374e+06 104.702315
#               0.60          5130 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.339261e+06 174.849430
#               0.65          5003        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 1.012285e+06  94.457049
#               0.65          5003       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 1.012285e+06  94.457049
#               0.65          5003       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 1.012285e+06  94.457049
#               0.65          5003          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.019050e+06 101.416256
#               0.65          5003        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.024980e+06 101.542701
#               0.65          5003                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.183233e+06 104.650735
#               0.65          5003                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.294699e+06 108.118395
#               0.65          5003                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.335432e+06 138.782524
#               0.65          5003 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 4.038305e+06 194.819575
#               0.70          4124        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 9.881605e+05  93.202417
#               0.70          4124       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 9.881605e+05  93.202417
#               0.70          4124       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 9.881605e+05  93.202417
#               0.70          4124          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.006118e+06 100.367182
#               0.70          4124        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.009548e+06 100.320810
#               0.70          4124                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.069856e+06  98.858839
#               0.70          4124                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.217600e+06 104.178428
#               0.70          4124                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.788656e+06 151.781055
#               0.70          4124 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.908803e+06 191.065806
#               0.75          3720        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 9.629030e+05  91.419555
#               0.75          3720       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 9.629030e+05  91.419555
#               0.75          3720       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 9.629030e+05  91.419555
#               0.75          3720        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 9.729942e+05  98.138879
#               0.75          3720          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 9.746015e+05  98.396091
#               0.75          3720                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.079313e+06  98.988884
#               0.75          3720                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.164417e+06 101.739864
#               0.75          3720                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.660588e+06 146.891850
#               0.75          3720 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.670280e+06 184.387792
#               0.80          3202        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.009761e+06 101.082996
#               0.80          3202        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 1.014927e+06  94.514620
#               0.80          3202       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 1.014932e+06  94.514765
#               0.80          3202       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 1.014932e+06  94.514765
#               0.80          3202          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.016646e+06 101.423811
#               0.80          3202                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.141285e+06 102.309192
#               0.80          3202                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.310080e+06 107.407339
#               0.80          3202                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.512880e+06 143.089738
#               0.80          3202 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.283508e+06 170.989949
#               0.85          2633        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.018157e+06  99.757140
#               0.85          2633          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.018880e+06  99.953958
#               0.85          2633        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 1.028633e+06  94.105455
#               0.85          2633       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 1.028633e+06  94.105455
#               0.85          2633       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 1.028633e+06  94.105455
#               0.85          2633                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.135980e+06 101.399406
#               0.85          2633                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.186899e+06 102.693686
#               0.85          2633                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.985968e+06 158.220042
#               0.85          2633 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.780628e+06 186.524631
#               0.90          2360        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.016892e+06 100.415010
#               0.90          2360          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.019581e+06 100.614247
#               0.90          2360        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 1.020503e+06  94.214185
#               0.90          2360       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 1.020503e+06  94.214185
#               0.90          2360       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 1.020503e+06  94.214185
#               0.90          2360                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.095355e+06  99.215442
#               0.90          2360                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.215599e+06 102.557717
#               0.90          2360                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 2.903464e+06 154.221512
#               0.90          2360 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.691575e+06 183.533057
#               0.95          2121        {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'median'} 1.012336e+06 101.627111
#               0.95          2121          {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'mean'} 1.017458e+06 101.932767
#               0.95          2121        {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5} 1.018091e+06  95.494549
#               0.95          2121       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 10} 1.018091e+06  95.494549
#               0.95          2121       {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 20} 1.018091e+06  95.494549
#               0.95          2121                        {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 10} 1.126560e+06 101.421110
#               0.95          2121                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 5} 1.166135e+06 102.623874
#               0.95          2121                         {'imputer': KNNImputer(n_neighbors=10), 'imputer__n_neighbors': 2} 3.132534e+06 162.060467
#               0.95          2121 {'imputer': SimpleImputer(strategy='most_frequent'), 'imputer__strategy': 'most_frequent'} 3.571589e+06 180.135932
#
# ===== Best Imputation Strategy =====
# Missing Threshold: 75.0%
# Removed Rows: 3720
# Best Params: {'imputer': IterativeImputer(max_iter=20, random_state=42), 'imputer__max_iter': 5}
# Best MSE: 962903.006523
# Best MAE: 91.419555
